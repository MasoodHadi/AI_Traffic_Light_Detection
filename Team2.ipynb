# %% [markdown]
# <a href="https://colab.research.google.com/github/MasoodHadi/AI_Traffic_Light_Detection/blob/main/Team2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 27.99 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# /content/yolov5

# %%
# Install required libraries
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 39.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import yaml
import os

# # Define paths
# yaml_file = "/content/drive/MyDrive/dataset_additional_rgb/additional_train.yaml"
# image_folder = "/content/drive/MyDrive/dataset_additional_rgb/test/images/"
# output_label_folder = "/content/drive/MyDrive/dataset_additional_rgb/test/labels/"

# Change paths to point to the training set
yaml_file = "/content/drive/MyDrive/dataset_additional_rgb/additional_train.yaml"
image_folder = "/content/drive/MyDrive/dataset_additional_rgb/train/images/"
output_label_folder = "/content/drive/MyDrive/dataset_additional_rgb/train/labels/"



# Ensure the output folder exists
os.makedirs(output_label_folder, exist_ok=True)

# Define class mappings
class_mapping = {"Red": 0, "Yellow": 1, "Green": 2,}

# Load YAML file
with open(yaml_file, 'r') as file:
    data = yaml.safe_load(file)

# Convert each annotation entry
for entry in data:
    image_path = entry["path"]
    boxes = entry["boxes"]

    # Extract image filename (without extension)
    image_filename = os.path.basename(image_path).replace(".png", ".txt")

    # Open the corresponding label file for writing
    label_file_path = os.path.join(output_label_folder, image_filename)
    with open(label_file_path, "w") as label_file:
        for box in boxes:
            class_name = box["label"]
            if class_name in class_mapping:
                class_id = class_mapping[class_name]

                # Extract bounding box coordinates
                x_min, y_min = box["x_min"], box["y_min"]
                x_max, y_max = box["x_max"], box["y_max"]

                # Convert to YOLO format (normalized)
                x_center = (x_min + x_max) / 2 / 1280  # Assuming image width = 1280
                y_center = (y_min + y_max) / 2 / 720   # Assuming image height = 720
                width = (x_max - x_min) / 1280
                height = (y_max - y_min) / 720

                # Write to label file
                label_file.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

print("Conversion completed! YOLO annotations saved in:", output_label_folder)
# Out:
# Conversion completed! YOLO annotations saved in: /content/drive/MyDrive/dataset_additional_rgb/train/labels/

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/drive/MyDrive/dataset_additional_rgb/data.yaml --weights yolov5s.pt --project /content/drive/MyDrive/MyTrainingOuputs_4
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-16 19:56:29.309361: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739735789.742222    5703 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739735789.859395    5703 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...
